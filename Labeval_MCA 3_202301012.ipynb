# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('company_sales_data.csv')
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("company_sales_data.csv")
total_sales = data.drop(['month_number', 'total_units', 'total_profit','toothpaste','bathingsoap','shampoo','moisturizer'], axis=1).sum()
plt.bar(total_sales.index, total_sales.values)
plt.title('Total Sales for Each Product')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.show()

# %%
profit=data['total_profit']
month=data['month_number']
sns.histplot(x=month, y=profit)
plt.show()

# %%
plt.hist(
